# %% [markdown]
# # Pocket Med Guard — Demo Notebook\nThis notebook demonstrates the local demo of the multi-agent pipeline.

# %%
from app.agents import ConversationAgent\nagent = ConversationAgent()\nres = __import__('asyncio').run(agent.handle_message('user1', 'Does turmeric cure cancer?'))\nres

# %% [markdown]
# Run evaluation:

# %%
from app import eval\neval.run_eval()
